# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("student_multi.csv")

# %%
df.head()
# Out:
#   course_name  class_number  study_hours  last_exam_score  exam_score
# 0     History             1          4.1               65          61
# 1        Math             2          9.5               65          95
# 2        Math             3          7.5               55          90
# 3     History             1          6.2               72          80
# 4     Physics             2          2.0               56          45

# %%
df.tail()
# Out:
#      course_name  class_number  study_hours  last_exam_score  exam_score
# 1610        Math             3          5.7               83          67
# 1611     History             4          2.3               95          49
# 1612     Physics             1          0.7               48          32
# 1613     History             2          7.3               77          82
# 1614     Physics             1          0.5               33          20

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   course_name      1615 non-null   object
#  1   class_number     1615 non-null   int64
#  2   study_hours      1615 non-null   float64
#  3   last_exam_score  1615 non-null   int64
#  4   exam_score       1615 non-null   int64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 63.2+ KB

# %%
df["course_name"].unique()
#also u can use .nunique() to see how many unique values in the column
# Out:
# array(['History', 'Math', 'Physics'], dtype=object)

# %%
df=pd.get_dummies(df,columns=["course_name"],drop_first=True)
# we used drop_firts to avoid dummy variable, if we have n unique variables in the column we can represent them with n-1 dummy variables
# or u can use label encoder
_="""
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["course_name"]=le.fit_transform(df["course_name"])
"""

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   class_number         1615 non-null   int64
#  1   study_hours          1615 non-null   float64
#  2   last_exam_score      1615 non-null   int64
#  3   exam_score           1615 non-null   int64
#  4   course_name_Math     1615 non-null   bool
#  5   course_name_Physics  1615 non-null   bool
# dtypes: bool(2), float64(1), int64(3)
# memory usage: 53.8 KB

# %%
# check if there any null values in the dataset
df.isnull().sum()
# Out:
# class_number           0
# study_hours            0
# last_exam_score        0
# exam_score             0
# course_name_Math       0
# course_name_Physics    0
# dtype: int64

# %%
df.head(10)
# Out:
#    class_number  study_hours  last_exam_score  exam_score  course_name_Math  \
# 0             1          4.1               65          61             False
# 1             2          9.5               65          95              True
# 2             3          7.5               55          90              True
# 3             1          6.2               72          80             False
# 4             2          2.0               56          45             False
# 5             3          2.0               38          36             False
# 6             3          1.0               81          32             False
# 7             1          9.0               79         100              True
# 8             1          6.2               94          76              True
# 9             3          7.2               50          77             False
#
#    course_name_Physics
# 0                False
# 1                False
# 2                False
# 3                False
# ...

# %%
y=df["exam_score"]
x=df.drop(["exam_score"],axis=1)

# %% [markdown]
# Linear regression example

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.6,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
lr.score(x_test,y_test)
# Out:
# 0.9806977791288921

# %%
df["predict"]=lr.predict(x)

# %%
df.head(10)
# Out:
#    class_number  study_hours  last_exam_score  exam_score  course_name_Math  \
# 0             1          4.1               65          61             False
# 1             2          9.5               65          95              True
# 2             3          7.5               55          90              True
# 3             1          6.2               72          80             False
# 4             2          2.0               56          45             False
# 5             3          2.0               38          36             False
# 6             3          1.0               81          32             False
# 7             1          9.0               79         100              True
# 8             1          6.2               94          76              True
# 9             3          7.2               50          77             False
#
#    course_name_Physics    predict
# 0                False  58.300379
# 1                False  97.282248
# ...

# %% [markdown]
# Compare Linear Models

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
models=[
    LinearRegression(),
    Ridge(),
    Lasso()
]

def evaluateModels():
    for x in models:
        model=x
        model.fit(x_train,y_train)
        score=model.score(x_test,y_test)
        name=x.__class__.__name__
        print(name,score)

evaluateModels()
# Out:
# LinearRegression 0.9806977791288921
# Ridge 0.9806992814514716
# Lasso 0.9798031130156238
